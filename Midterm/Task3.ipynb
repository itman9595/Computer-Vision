# %%
from scipy import ndimage 
import numpy as np 
import matplotlib.image as img 
import matplotlib.pyplot as plt 
from skimage import color 
from skimage import io 
from skimage import util 

import matplotlib.image as pltimg 
image = io.imread('shawnMendes.jpg', as_grey=True) 
image_s_p = util.random_noise(image, mode='s&p', seed=None, clip=True) 
flt = ndimage.median_filter(image, 3) 

fig = plt.figure(figsize=(35,35)) 
plt.subplot(231) 
plt.title('Original') 
plt.imshow(image,cmap='gray') 


plt.subplot(232) 
plt.title('S&P') 
plt.imshow(image_s_p,cmap='gray') 
plt.subplot(233) 
plt.title('Median Filter') 
plt.imshow(flt,cmap='gray') 

plt.subplot(234) 
plt.title('Difference between original & S&P') 
plt.imshow(image-image_s_p,cmap='gray')
plt.subplot(235) 
plt.title('Difference between original & Median Filter') 
plt.imshow(image-flt,cmap='gray')

plt.show()
